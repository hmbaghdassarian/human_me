# %%
import cobra
import sys
# sys.path.insert(1, '../scripts/')
# from utils import *
# Out:
# load environmental variables
# The project root is: /Users/joycebaghdassarian/Documents/UCSD/Lewis_Lab/Projects/human_me/

# %%
biomass = cobra.Metabolite('biomass')
biomass_strings = ['protein_biomass', 'mRNA_biomass', 'tRNA_biomass', 'rRNA_biomass', 'ncRNA_biomass', 
                   'DNA_biomass', 'lipid_biomass', 'constituent_biomass', 'prosthetic_group_biomass', 
                   'peptidoglycan_biomass']

biomass_constituents = [cobra.Metabolite(s) for s in biomass_strings]

# %%
orig_biomass = [m for m in human_model.metabolites if 'biomass' in m.id]

# %%
orig_biomass
# Out:
# [<Metabolite biomass_protein[c] at 0x7fb66f50d358>,
#  <Metabolite biomass_DNA[c] at 0x7fb66f50d390>,
#  <Metabolite biomass_RNA[c] at 0x7fb66f50d3c8>,
#  <Metabolite biomass_carbohydrate[c] at 0x7fb66f50d400>,
#  <Metabolite biomass_lipid[c] at 0x7fb66f50d438>,
#  <Metabolite biomass_other[c] at 0x7fb66f50d470>]

# %%
list(human_model.metabolites.get_by_id('biomass_DNA[c]').reactions)[0]
# Out:
# <Reaction biomass_DNA at 0x7fb672796b38>
