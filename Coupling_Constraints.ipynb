# %% [markdown]
# # The Reactions in Their Current Format

# %% [markdown]
# $$i \in mRNA$$
# $$j \in protein$$
# i,j correspond to 1 gene
#
# v_formation,i: substrates_m --> mRNA_i + (MW_i)biomass_mRNA \
# v_degradation,i: mRNA_i + (MW_i)biomass_mRNA --> products_m + deg_i_proxy
#
# v_synthesis,j: substrates_p + (c1)mRNA_i + (c2)deg_i_proxy --> protein +
